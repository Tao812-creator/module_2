# %% [markdown]
# ## Pandas, Correlation and probability Distributions.
# We used 'pandas in the last session' eg loading the data sets
# a series - a single labelled 1 dimensional array(one column of spreadsheet with an index)
# a dataframe - a two dimensional table table(a collection of series that share the same index)

# %%
import pandas as pd
import numpy as np

# a series has to be indexed and labelled
#series A
ages = pd.Series([29, 34, 41, 22, 37, 26], name='age')
ages
# Out:
# 0    29
# 1    34
# 2    41
# 3    22
# 4    37
# 5    26
# Name: age, dtype: int64

# %%
ages.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 6 entries, 0 to 5
# Series name: age
# Non-Null Count  Dtype
# --------------  -----
# 6 non-null      int64
# dtypes: int64(1)
# memory usage: 180.0 bytes

# %%
ages.values
# Out:
# array([29, 34, 41, 22, 37, 26], dtype=int64)

# %%
ages.name
# Out:
# 'age'

# %%
ages.index.tolist()
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
ages.head()
# Out:
# 0    29
# 1    34
# 2    41
# 3    22
# 4    37
# Name: age, dtype: int64

# %%
#lets create a custom index
named_ages = pd.Series(
    [29, 34, 41, 22, 37, 26],
    index = ['brian', 'bob', 'cynthia', 'david', 'eve', 'frank'],
    name = 'age'
)
named_ages
# Out:
# brian      29
# bob        34
# cynthia    41
# david      22
# eve        37
# frank      26
# Name: age, dtype: int64

# %%
#access using label
named_ages['eve']
# Out:
# 37

# %%
#acess using position
named_ages.iloc[4]
# Out:
# 37

# %% [markdown]
# 1. difference between iloc and loc
# the function of these two first of all difference between iloc and loc is that iloc is used for integer-location based indexing, while loc is used for label-based indexing. i.e iloc uses index location while loc uses label location
#
#
#
# 2. correlation vs causation
# 3. types of probability distributions

# %%
ages.loc[0]
# Out:
# 0    29
# 1    34
# 2    41
# Name: age, dtype: int64

# %%
named_ages.loc['brian']
# Out:
# 29

# %%
named_ages.iloc[0:2]
# Out:
# brian    29
# bob      34
# Name: age, dtype: int64

# %%
from sklearn.datasets import load_iris

iris = load_iris(as )

# %%
df = named_ages.copy()

df[df['age']>30]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\nssf\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'age'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 3
#       1 df = named_ages.copy()
# ----> 3 df[df['age']>30]
#
# File c:\Users\nssf\anaconda3\Lib\site-packages\pandas\core\series.py:1040, in Series.__getitem__(self, key)
#    1037     return self._values[key]
#    1039 elif key_is_scalar:
# -> 1040     return self._get_value(key)
#    1042 # Convert generator to list before going through hashable part
#    1043 # (We will iterate through the generator there to check for slices)
#    1044 if is_iterator(key):
#
# File c:\Users\nssf\anaconda3\Lib\site-packages\pandas\core\series.py:1156, in Series._get_value(self, label, takeable)
#    1153     return self._values[label]
#    1155 # Similar to Index.get_value, but we do not fall back to positional
# -> 1156 loc = self.index.get_loc(label)
#    1158 if is_integer(loc):
#    1159     return self._values[loc]
#
# File c:\Users\nssf\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 'age'
